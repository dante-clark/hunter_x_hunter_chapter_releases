# %%
import pandas as pd
import seaborn as sns

sns.set_theme()

data = pd.read_csv("./csv_files/raw_data.csv")


sns.lineplot(data=data, x="japanese release", y='chapters')
# Out:
# <AxesSubplot:xlabel='japanese release', ylabel='chapters'>
